# %% [markdown]
# # DL models in Keras

# %% [markdown]
# Import pandas, numpy,<br />
# Dense layer and Sequential model from keras

# %%
import pandas as pd
import numpy as np
from keras.layers import Dense
from keras.models import Sequential
from sklearn.model_selection import train_test_split

# %% [markdown]
# Read the dataset

# %%
dataset = pd.read_csv('hourly_wages.csv')

# %% [markdown]
# Explore the datasets first five samples

# %%
dataset.head(5)
# Out:
#    wage_per_hour  union  education_yrs  experience_yrs  age  female  marr  \
# 0           5.10      0              8              21   35       1     1
# 1           4.95      0              9              42   57       1     1
# 2           6.67      0             12               1   19       0     0
# 3           4.00      0             12               4   22       0     0
# 4           7.50      0             12              17   35       0     1
#
#    south  manufacturing  construction
# 0      0              1             0
# 1      0              1             0
# 2      0              1             0
# 3      0              0             0
# 4      0              0             0

# %% [markdown]
# Check the datasets structure by calling the <i>describe</i> method

# %%
dataset.describe()
# Out:
#        wage_per_hour       union  education_yrs  experience_yrs         age  \
# count     534.000000  534.000000     534.000000      534.000000  534.000000
# mean        9.024064    0.179775      13.018727       17.822097   36.833333
# std         5.139097    0.384360       2.615373       12.379710   11.726573
# min         1.000000    0.000000       2.000000        0.000000   18.000000
# 25%         5.250000    0.000000      12.000000        8.000000   28.000000
# 50%         7.780000    0.000000      12.000000       15.000000   35.000000
# 75%        11.250000    0.000000      15.000000       26.000000   44.000000
# max        44.500000    1.000000      18.000000       55.000000   64.000000
#
#            female        marr       south  manufacturing  construction
# count  534.000000  534.000000  534.000000     534.000000    534.000000
# mean     0.458801    0.655431    0.292135       0.185393      0.044944
# std      0.498767    0.475673    0.455170       0.388981      0.207375
# min      0.000000    0.000000    0.000000       0.000000      0.000000
# 25%      0.000000    0.000000    0.000000       0.000000      0.000000
# 50%      0.000000    1.000000    0.000000       0.000000      0.000000
# 75%      1.000000    1.000000    1.000000       0.000000      0.000000
# max      1.000000    1.000000    1.000000       1.000000      1.000000

# %% [markdown]
# Split the dataset into inputs and outputs. Here, you want to predict the hourly wage number.

# %%
predictors = dataset.iloc[:, 1:].as_matrix()
target = dataset.iloc[:, 0:1].as_matrix()

# %%
X_train, X_test, y_train, y_test = train_test_split(predictors, target, random_state=0, test_size=0.2)

# %% [markdown]
# You have to define the input shape for the first layer in neural network. The shape of the <i>predictors</i> (number of columns in particular) should help you with this.

# %%
predictors.shape[1]
# Out:
# 9

# %%
n_cols = predictors.shape[1]

# %% [markdown]
# Build the simple sequential model of NN

# %%
model = Sequential()

# %% [markdown]
# <b>Add</b> the first layer with 50 units (neurons). Give it the activation of <b>relu</b> type and provide it with the <b>input shape</b>

# %%
model.add(Dense(50, activation='relu', input_shape=(n_cols,)))

# %% [markdown]
# <b>Add</b> the first layer with 32 units. Give it the activation of <b>relu</b> type. Is it necessary to define the input shape? What are your thoughts?

# %%
model.add(Dense(32, activation='relu'))

# %% [markdown]
# <b>Add</b> the output layer. How many units should be here? Recall that you have a regression problem here.

# %%
model.add(Dense(1))

# %% [markdown]
# Check the models summary. The model should contain only dense layers, among them the last one is an output layer.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 50)                500
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                1632
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 2,165
# Trainable params: 2,165
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# You're now going to compile the model you specified earlier. To compile the model, you need to specify the optimizer and loss function to use.
#
# The Adam optimizer is an excellent choice. You can read more about it as well as other keras optimizers <a href="https://keras.io/optimizers/#adam">here</a>, and if you are really curious to learn more, you can read the original <a href="https://arxiv.org/abs/1412.6980v8">paper</a> that introduced the Adam optimizer.
#
# In this exercise, you'll use the Adam optimizer and the mean squared error loss function.

# %%
from keras.optimizers import RMSprop, Adam
# optimizer = RMSprop(lr=0.001)
optimizer = Adam(lr=0.001)

# %%
model.compile(optimizer=optimizer, loss='mean_squared_logarithmic_error')

# %% [markdown]
# You'll now fit the model. Recall that the data to be used as predictive features is loaded in a NumPy matrix called predictors and the data to be predicted is stored in a NumPy matrix called target.
#
# You can specify the number of epochs. By default it is ten.

# %%
model.fit(predictors, target)
# Out:
# Epoch 1/1
# 534/534 [==============================] - 1s 2ms/step - loss: 0.1600

# %% [markdown]
# Now you can either predict the values feeding into the <i>predict</i> method your <i>predictors</i> array, OR you can go back to the beginning and split the dataset into train and test. Then you can test it on the test set

# %%
y_preds = model.predict(predictors)

# %% [markdown]
# You can check the predicted values and difference between actual ones

# %%
for i,j in zip(target,y_preds):
    print('true ', i, ' pred ', j, ' diff ', i-j)
# Out:
# true  [5.1]  pred  [5.7235966]  diff  [-0.62359657]
# true  [4.95]  pred  [6.317479]  diff  [-1.36747913]
# true  [6.67]  pred  [5.91361]  diff  [0.75639002]
# true  [4.]  pred  [6.3918924]  diff  [-2.39189243]
# true  [7.5]  pred  [8.261326]  diff  [-0.76132584]
# true  [13.07]  pred  [8.067015]  diff  [5.00298531]
# true  [4.45]  pred  [7.015392]  diff  [-2.56539183]
# true  [19.47]  pred  [7.404896]  diff  [12.06510422]
# true  [13.28]  pred  [9.469692]  diff  [3.81030777]
# true  [8.75]  pred  [7.404896]  diff  [1.34510422]
# true  [11.35]  pred  [8.753997]  diff  [2.59600315]
# true  [11.5]  pred  [9.024801]  diff  [2.47519875]
# true  [6.5]  pred  [5.787815]  diff  [0.71218491]
# true  [6.25]  pred  [6.826989]  diff  [-0.57698917]
# true  [19.98]  pred  [6.395885]  diff  [13.58411501]
# true  [7.3]  pred  [8.441322]  diff  [-1.14132233]
# true  [8.]  pred  [5.81596]  diff  [2.18404007]
# true  [22.2]  pred  [9.181212]  diff  [13.01878757]
# true  [3.65]  pred  [7.640647]  diff  [-3.99064693]
# true  [20.55]  pred  [8.493962]  diff  [12.05603771]
# true  [5.71]  pred  [8.420969]  diff  [-2.71096901]
# true  [7.]  pred  [6.110279]  diff  [0.88972092]
# true  [3.75]  pred  [7.404896]  diff  [-3.65489578]
# true  [4.5]  pred  [7.3191953]  diff  [-2.81919527]
# true  [9.56]  pred  [8.401875]  diff  [1.15812546]
# true  [5.75]  pred  [5.652567]  diff  [0.09743309]
# true  [9.36]  pred  [7.328684]  diff  [2.03131615]
# true  [6.5]  pred  [7.259518]  diff  [-0.75951815]
# true  [3.35]  pred  [6.9064283]  diff  [-3.55642834]
# true  [4.75]  pred  [7.20737]  diff  [-2.4573698]
# true  [8.9]  pred  [8.95549]  diff  [-0.05549011]
# true  [4.]  pred  [7.655162]  diff  [-3.65516186]
# true  [4.7]  pred  [5.9849353]  diff  [-1.28493528]
# true  [5.]  pred  [7.0497]  diff  [-2.04969978]
# true  [9.25]  pred  [8.526772]  diff  [0.72322845]
# true  [10.67]  pred  [8.479158]  diff  [2.1908416]
# true  [7.61]  pred  [7.9978447]  diff  [-0.3878447]
# true  [10.]  pred  [8.887231]  diff  [1.11276913]
# true  [7.5]  pred  [6.188587]  diff  [1.31141281]
# true  [12.2]  pred  [8.199262]  diff  [4.00073833]
# true  [3.35]  pred  [5.590594]  diff  [-2.24059381]
# true  [11.]  pred  [9.242438]  diff  [1.75756168]
# true  [12.]  pred  [8.366078]  diff  [3.63392162]
# true  [4.85]  pred  [6.2608094]  diff  [-1.41080942]
# true  [4.3]  pred  [7.280109]  diff  [-2.98010893]
# true  [6.]  pred  [4.8011293]  diff  [1.19887066]
# true  [15.]  pred  [9.672998]  diff  [5.32700157]
# true  [4.85]  pred  [6.699034]  diff  [-1.84903421]
# true  [9.]  pred  [6.4499483]  diff  [2.55005169]
# true  [6.36]  pred  [7.5228624]  diff  [-1.16286243]
# true  [9.15]  pred  [7.0040646]  diff  [2.14593544]
# true  [11.]  pred  [10.125001]  diff  [0.87499905]
# true  [4.5]  pred  [6.7122507]  diff  [-2.21225071]
# true  [4.8]  pred  [7.9453473]  diff  [-3.14534731]
# true  [4.]  pred  [5.972887]  diff  [-1.97288704]
# true  [5.5]  pred  [7.4300613]  diff  [-1.93006134]
# true  [8.4]  pred  [9.021116]  diff  [-0.62111626]
# true  [6.75]  pred  [7.2287903]  diff  [-0.47879028]
# true  [10.]  pred  [9.092251]  diff  [0.90774918]
# true  [5.]  pred  [8.190308]  diff  [-3.19030762]
# true  [6.5]  pred  [7.677266]  diff  [-1.17726612]
# true  [10.75]  pred  [8.845854]  diff  [1.90414619]
# true  [7.]  pred  [5.4297504]  diff  [1.57024956]
# true  [11.43]  pred  [5.918296]  diff  [5.51170414]
# true  [4.]  pred  [7.193127]  diff  [-3.19312716]
# true  [9.]  pred  [7.225282]  diff  [1.77471781]
# true  [13.]  pred  [8.772453]  diff  [4.22754669]
# true  [12.22]  pred  [8.738819]  diff  [3.48118088]
# true  [6.28]  pred  [8.161958]  diff  [-1.88195774]
# true  [6.75]  pred  [7.6598973]  diff  [-0.90989733]
# true  [3.35]  pred  [5.6421323]  diff  [-2.29213228]
# true  [16.]  pred  [9.978613]  diff  [6.0213871]
# true  [5.25]  pred  [7.0735283]  diff  [-1.82352829]
# true  [3.5]  pred  [5.359214]  diff  [-1.85921383]
# true  [4.22]  pred  [5.566143]  diff  [-1.34614304]
# true  [3.]  pred  [5.4596233]  diff  [-2.45962334]
# true  [4.]  pred  [7.7731495]  diff  [-3.77314949]
# true  [10.]  pred  [8.0733795]  diff  [1.92662048]
# true  [5.]  pred  [7.938097]  diff  [-2.938097]
# true  [16.]  pred  [8.918004]  diff  [7.08199596]
# true  [13.98]  pred  [9.105168]  diff  [4.87483166]
# true  [13.26]  pred  [8.717379]  diff  [4.54262138]
# true  [6.1]  pred  [7.3375854]  diff  [-1.23758545]
# true  [3.75]  pred  [8.944374]  diff  [-5.19437408]
# true  [9.]  pred  [7.9771395]  diff  [1.02286053]
# true  [9.45]  pred  [8.231596]  diff  [1.21840401]
# true  [5.5]  pred  [8.223557]  diff  [-2.72355747]
# true  [8.93]  pred  [7.790085]  diff  [1.13991516]
# true  [6.25]  pred  [6.0704556]  diff  [0.17954445]
# true  [9.75]  pred  [8.291579]  diff  [1.45842075]
# true  [6.73]  pred  [5.8433237]  diff  [0.88667629]
# true  [7.78]  pred  [8.636749]  diff  [-0.85674927]
# true  [2.85]  pred  [5.788382]  diff  [-2.93838205]
# true  [3.35]  pred  [6.89843]  diff  [-3.54842987]
# true  [19.98]  pred  [8.636749]  diff  [11.34325073]
# true  [8.5]  pred  [7.486704]  diff  [1.01329613]
# true  [9.75]  pred  [8.287575]  diff  [1.46242523]
# true  [15.]  pred  [8.8924885]  diff  [6.10751152]
# true  [8.]  pred  [8.055514]  diff  [-0.05551434]
# true  [11.25]  pred  [8.692914]  diff  [2.55708599]
# true  [14.]  pred  [7.9664993]  diff  [6.03350067]
# true  [10.]  pred  [6.874589]  diff  [3.12541103]
# true  [6.5]  pred  [7.2051144]  diff  [-0.70511436]
# true  [9.83]  pred  [8.636749]  diff  [1.19325073]
# true  [18.5]  pred  [8.612082]  diff  [9.88791847]
# true  [12.5]  pred  [7.0650954]  diff  [5.43490458]
# true  [26.]  pred  [10.015231]  diff  [15.98476887]
# true  [14.]  pred  [5.146222]  diff  [8.85377789]
# true  [10.5]  pred  [6.673482]  diff  [3.82651806]
# true  [11.]  pred  [6.244473]  diff  [4.75552702]
# true  [12.47]  pred  [8.2748575]  diff  [4.19514248]
# true  [12.5]  pred  [7.7345533]  diff  [4.76544666]
# true  [15.]  pred  [8.8740835]  diff  [6.12591648]
# true  [6.]  pred  [7.1935434]  diff  [-1.19354343]
# true  [9.5]  pred  [7.5960917]  diff  [1.90390825]
# true  [5.]  pred  [7.998151]  diff  [-2.99815083]
# true  [3.75]  pred  [7.2907743]  diff  [-3.54077435]
# true  [12.57]  pred  [8.267558]  diff  [4.3024419]
# true  [6.88]  pred  [5.485708]  diff  [1.39429176]
# true  [5.5]  pred  [7.938097]  diff  [-2.438097]
# true  [7.]  pred  [7.2833977]  diff  [-0.28339767]
# true  [4.5]  pred  [7.8825517]  diff  [-3.38255167]
# true  [6.5]  pred  [8.48609]  diff  [-1.98608971]
# true  [12.]  pred  [8.795039]  diff  [3.20496082]
# true  [5.]  pred  [6.496096]  diff  [-1.49609613]
# true  [6.5]  pred  [6.423394]  diff  [0.0766058]
# true  [6.8]  pred  [6.084675]  diff  [0.71532516]
# true  [8.75]  pred  [8.855225]  diff  [-0.10522461]
# true  [3.75]  pred  [6.208981]  diff  [-2.45898104]
# true  [4.5]  pred  [7.923648]  diff  [-3.42364788]
# true  [6.]  pred  [5.797017]  diff  [0.2029829]
# true  [5.5]  pred  [6.3107624]  diff  [-0.81076241]
# true  [13.]  pred  [7.20737]  diff  [5.7926302]
# true  [5.65]  pred  [6.875982]  diff  [-1.22598181]
# true  [4.8]  pred  [6.730998]  diff  [-1.93099804]
# true  [7.]  pred  [6.20862]  diff  [0.79137993]
# true  [5.25]  pred  [5.9861693]  diff  [-0.73616934]
# true  [3.35]  pred  [5.831545]  diff  [-2.48154488]
# true  [8.5]  pred  [6.852049]  diff  [1.64795113]
# true  [6.]  pred  [7.410675]  diff  [-1.41067505]
# true  [6.75]  pred  [7.571515]  diff  [-0.82151508]
# true  [8.89]  pred  [8.523816]  diff  [0.36618389]
# true  [14.21]  pred  [8.325525]  diff  [5.88447472]
# true  [10.78]  pred  [8.039372]  diff  [2.74062756]
# true  [8.9]  pred  [7.420835]  diff  [1.47916498]
# true  [7.5]  pred  [8.235718]  diff  [-0.73571777]
# true  [4.5]  pred  [5.921873]  diff  [-1.42187309]
# true  [11.25]  pred  [8.913578]  diff  [2.33642197]
# true  [13.45]  pred  [8.43174]  diff  [5.01826019]
# true  [6.]  pred  [7.2210703]  diff  [-1.22107029]
# true  [4.62]  pred  [4.4533606]  diff  [0.16663944]
# true  [10.58]  pred  [9.833735]  diff  [0.74626453]
# true  [5.]  pred  [6.3259015]  diff  [-1.32590151]
# true  [8.2]  pred  [9.07482]  diff  [-0.87481956]
# true  [6.25]  pred  [5.5208926]  diff  [0.72910738]
# true  [8.5]  pred  [8.245719]  diff  [0.25428104]
# true  [24.98]  pred  [10.526753]  diff  [14.45324657]
# true  [16.65]  pred  [9.247782]  diff  [7.40221825]
# true  [6.25]  pred  [6.7507534]  diff  [-0.5007534]
# true  [4.55]  pred  [5.7026577]  diff  [-1.1526577]
# true  [11.25]  pred  [7.7051883]  diff  [3.54481173]
# true  [21.25]  pred  [9.110841]  diff  [12.1391592]
# true  [12.65]  pred  [9.729834]  diff  [2.9201664]
# true  [7.5]  pred  [8.234644]  diff  [-0.73464394]
# true  [10.25]  pred  [9.125203]  diff  [1.12479687]
# true  [3.35]  pred  [8.938652]  diff  [-5.58865204]
# true  [13.45]  pred  [8.735346]  diff  [4.71465416]
# true  [4.84]  pred  [7.1981044]  diff  [-2.35810438]
# true  [26.29]  pred  [11.219824]  diff  [15.07017616]
# true  [6.58]  pred  [7.9169283]  diff  [-1.33692829]
# true  [44.5]  pred  [6.1620407]  diff  [38.33795929]
# true  [15.]  pred  [8.704045]  diff  [6.2959547]
# true  [11.25]  pred  [7.453863]  diff  [3.79613686]
# true  [7.]  pred  [7.9439845]  diff  [-0.94398451]
# true  [10.]  pred  [9.523705]  diff  [0.47629547]
# true  [14.53]  pred  [10.526753]  diff  [4.00324657]
# true  [20.]  pred  [11.120411]  diff  [8.87958908]
# true  [22.5]  pred  [9.168264]  diff  [13.33173561]
# true  [3.64]  pred  [7.917691]  diff  [-4.27769123]
# true  [10.62]  pred  [8.246235]  diff  [2.37376511]
# true  [24.98]  pred  [12.005362]  diff  [12.97463844]
# true  [6.]  pred  [8.463795]  diff  [-2.46379471]
# true  [19.]  pred  [10.639164]  diff  [8.36083603]
# true  [13.2]  pred  [9.141956]  diff  [4.05804367]
# true  [22.5]  pred  [10.673644]  diff  [11.82635593]
# true  [15.]  pred  [8.87266]  diff  [6.12734032]
# true  [6.88]  pred  [10.069189]  diff  [-3.18918907]
# true  [11.84]  pred  [8.4498825]  diff  [3.39011749]
# true  [16.14]  pred  [9.31278]  diff  [6.82721962]
# true  [13.95]  pred  [10.317737]  diff  [3.63226337]
# true  [13.16]  pred  [7.9282093]  diff  [5.2317907]
# true  [5.3]  pred  [7.8740597]  diff  [-2.57405968]
# true  [4.5]  pred  [6.6033945]  diff  [-2.10339451]
# true  [10.]  pred  [9.79051]  diff  [0.20948982]
# true  [10.]  pred  [7.177403]  diff  [2.82259703]
# true  [10.]  pred  [8.806131]  diff  [1.19386864]
# true  [9.37]  pred  [10.295904]  diff  [-0.92590416]
# true  [5.8]  pred  [9.953342]  diff  [-4.15334244]
# true  [17.86]  pred  [9.100325]  diff  [8.75967537]
# true  [1.]  pred  [8.417878]  diff  [-7.41787815]
# true  [8.8]  pred  [9.470161]  diff  [-0.67016144]
# true  [9.]  pred  [8.534295]  diff  [0.46570492]
# true  [18.16]  pred  [10.026919]  diff  [8.13308064]
# true  [7.81]  pred  [5.1267967]  diff  [2.68320328]
# true  [10.62]  pred  [8.066034]  diff  [2.55396568]
# true  [4.5]  pred  [5.803712]  diff  [-1.30371189]
# true  [17.25]  pred  [10.294595]  diff  [6.95540524]
# true  [10.5]  pred  [8.319761]  diff  [2.18023872]
# true  [9.22]  pred  [8.461911]  diff  [0.7580888]
# true  [15.]  pred  [11.50658]  diff  [3.49341965]
# true  [22.5]  pred  [10.7225485]  diff  [11.77745152]
# true  [4.55]  pred  [8.562522]  diff  [-4.01252193]
# true  [9.]  pred  [8.224604]  diff  [0.77539635]
# true  [13.33]  pred  [9.9093275]  diff  [3.42067249]
# true  [15.]  pred  [9.523705]  diff  [5.47629547]
# true  [7.5]  pred  [6.7507534]  diff  [0.7492466]
# true  [4.25]  pred  [7.7083893]  diff  [-3.45838928]
# true  [12.5]  pred  [8.701417]  diff  [3.79858303]
# true  [5.13]  pred  [6.2103233]  diff  [-1.08032333]
# true  [3.35]  pred  [9.110732]  diff  [-5.76073208]
# true  [11.11]  pred  [8.230463]  diff  [2.87953697]
# true  [3.84]  pred  [7.0858746]  diff  [-3.24587456]
# true  [6.4]  pred  [7.9166393]  diff  [-1.51663933]
# true  [5.56]  pred  [7.088762]  diff  [-1.52876181]
# true  [10.]  pred  [8.296593]  diff  [1.70340729]
# true  [5.65]  pred  [7.9438596]  diff  [-2.29385958]
# true  [11.5]  pred  [10.305597]  diff  [1.19440269]
# true  [3.5]  pred  [7.3201895]  diff  [-3.82018948]
# true  [3.35]  pred  [5.711412]  diff  [-2.36141195]
# true  [4.75]  pred  [6.7456827]  diff  [-1.99568272]
# true  [19.98]  pred  [9.462274]  diff  [10.5177264]
# true  [3.5]  pred  [6.8959894]  diff  [-3.39598942]
# true  [4.]  pred  [7.653845]  diff  [-3.65384483]
# true  [7.]  pred  [6.597453]  diff  [0.40254688]
# true  [6.25]  pred  [6.5117507]  diff  [-0.2617507]
# true  [4.5]  pred  [9.121848]  diff  [-4.62184811]
# true  [14.29]  pred  [9.186317]  diff  [5.10368256]
# true  [5.]  pred  [7.643194]  diff  [-2.6431942]
# true  [13.75]  pred  [9.521043]  diff  [4.22895718]
# true  [13.71]  pred  [8.908319]  diff  [4.80168053]
# true  [7.5]  pred  [7.7069273]  diff  [-0.2069273]
# true  [3.8]  pred  [6.004762]  diff  [-2.20476217]
# true  [5.]  pred  [6.3556366]  diff  [-1.3556366]
# true  [9.42]  pred  [8.251493]  diff  [1.16850655]
# true  [5.5]  pred  [8.346602]  diff  [-2.84660244]
# true  [3.75]  pred  [7.268014]  diff  [-3.51801395]
# true  [3.5]  pred  [8.491333]  diff  [-4.99133301]
# true  [5.8]  pred  [6.9777565]  diff  [-1.1777565]
# true  [12.]  pred  [10.258861]  diff  [1.74113941]
# true  [5.]  pred  [8.867715]  diff  [-3.86771488]
# true  [8.75]  pred  [7.1663013]  diff  [1.58369875]
# true  [10.]  pred  [8.147165]  diff  [1.8528347]
# true  [8.5]  pred  [7.9239235]  diff  [0.57607651]
# true  [8.63]  pred  [7.790085]  diff  [0.83991516]
# true  [9.]  pred  [10.540836]  diff  [-1.54083633]
# true  [5.5]  pred  [7.1283827]  diff  [-1.62838268]
# true  [11.11]  pred  [8.529972]  diff  [2.58002792]
# true  [10.]  pred  [9.079638]  diff  [0.92036247]
# true  [5.2]  pred  [9.78806]  diff  [-4.58806019]
# true  [8.]  pred  [9.115209]  diff  [-1.11520863]
# true  [3.56]  pred  [7.0490036]  diff  [-3.4890036]
# true  [5.2]  pred  [7.9169283]  diff  [-2.71692829]
# true  [11.67]  pred  [7.872941]  diff  [3.79705898]
# true  [11.32]  pred  [7.721903]  diff  [3.59809715]
# true  [7.5]  pred  [7.4418526]  diff  [0.05814743]
# true  [5.5]  pred  [7.3288975]  diff  [-1.82889748]
# true  [5.]  pred  [7.265697]  diff  [-2.265697]
# true  [7.75]  pred  [7.9169283]  diff  [-0.16692829]
# true  [5.25]  pred  [7.9166393]  diff  [-2.66663933]
# true  [9.]  pred  [8.844632]  diff  [0.15536785]
# true  [9.65]  pred  [7.9282093]  diff  [1.7217907]
# true  [5.21]  pred  [9.637775]  diff  [-4.42777542]
# true  [7.]  pred  [7.159463]  diff  [-0.15946293]
# true  [12.16]  pred  [7.6988873]  diff  [4.46111265]
# true  [5.25]  pred  [6.856924]  diff  [-1.60692406]
# true  [10.32]  pred  [8.301337]  diff  [2.01866276]
# true  [3.35]  pred  [7.718818]  diff  [-4.36881819]
# true  [7.7]  pred  [7.4505816]  diff  [0.24941845]
# true  [9.17]  pred  [8.146181]  diff  [1.02381889]
# true  [8.43]  pred  [7.571515]  diff  [0.85848492]
# true  [4.]  pred  [6.896288]  diff  [-2.89628792]
# true  [4.13]  pred  [6.007017]  diff  [-1.87701714]
# true  [3.]  pred  [7.71159]  diff  [-4.71158981]
# true  [4.25]  pred  [5.3316264]  diff  [-1.08162642]
# true  [7.53]  pred  [6.2854776]  diff  [1.24452236]
# true  [10.53]  pred  [8.448761]  diff  [2.08123901]
# true  [5.]  pred  [7.9255795]  diff  [-2.92557955]
# true  [15.03]  pred  [7.9169283]  diff  [7.11307171]
# true  [11.25]  pred  [10.985932]  diff  [0.26406765]
# true  [6.25]  pred  [7.922124]  diff  [-1.67212391]
# true  [3.5]  pred  [7.9239235]  diff  [-4.42392349]
# true  [6.85]  pred  [7.2051144]  diff  [-0.35511436]
# true  [12.5]  pred  [8.273816]  diff  [4.22618389]
# true  [12.]  pred  [6.3190904]  diff  [5.68090963]
# true  [6.]  pred  [9.113471]  diff  [-3.11347103]
# true  [9.5]  pred  [7.9239235]  diff  [1.57607651]
# true  [4.1]  pred  [7.6799164]  diff  [-3.57991638]
# true  [10.43]  pred  [8.409777]  diff  [2.02022331]
# true  [5.]  pred  [5.2041163]  diff  [-0.20411634]
# true  [7.69]  pred  [8.324058]  diff  [-0.63405758]
# true  [5.5]  pred  [7.8599124]  diff  [-2.3599124]
# true  [6.4]  pred  [6.400105]  diff  [-0.000105]
# true  [12.5]  pred  [8.053975]  diff  [4.44602489]
# true  [6.25]  pred  [8.57041]  diff  [-2.32040977]
# true  [8.]  pred  [6.7746506]  diff  [1.22534943]
# true  [9.6]  pred  [7.064199]  diff  [2.53580103]
# true  [9.1]  pred  [8.755402]  diff  [0.34459839]
# true  [7.5]  pred  [7.562671]  diff  [-0.06267118]
# true  [5.]  pred  [6.4910736]  diff  [-1.49107361]
# true  [7.]  pred  [7.4487057]  diff  [-0.44870567]
# true  [3.55]  pred  [5.5122604]  diff  [-1.96226044]
# true  [8.5]  pred  [5.718681]  diff  [2.78131914]
# true  [4.5]  pred  [5.3316264]  diff  [-0.83162642]
# true  [7.88]  pred  [10.465942]  diff  [-2.58594238]
# true  [5.25]  pred  [6.7746506]  diff  [-1.52465057]
# true  [5.]  pred  [6.120341]  diff  [-1.12034082]
# true  [9.33]  pred  [7.653845]  diff  [1.67615517]
# true  [10.5]  pred  [7.951874]  diff  [2.54812622]
# true  [7.5]  pred  [7.6333103]  diff  [-0.13331032]
# true  [9.5]  pred  [7.6839333]  diff  [1.81606674]
# true  [9.6]  pred  [7.3287487]  diff  [2.2712513]
# true  [5.87]  pred  [8.05261]  diff  [-2.1826104]
# true  [11.02]  pred  [8.749779]  diff  [2.27022125]
# true  [5.]  pred  [7.6802998]  diff  [-2.68029976]
# true  [5.62]  pred  [9.186317]  diff  [-3.56631744]
# true  [12.5]  pred  [7.561301]  diff  [4.93869877]
# true  [10.81]  pred  [7.9229507]  diff  [2.88704926]
# true  [5.4]  pred  [8.018791]  diff  [-2.6187912]
# true  [7.]  pred  [6.9191623]  diff  [0.08083773]
# true  [4.59]  pred  [7.6462464]  diff  [-3.05624643]
# true  [6.]  pred  [7.8268075]  diff  [-1.8268075]
# true  [11.71]  pred  [10.62919]  diff  [1.08080956]
# true  [5.62]  pred  [5.982964]  diff  [-0.36296404]
# true  [5.5]  pred  [7.9413557]  diff  [-2.44135571]
# true  [4.85]  pred  [7.3287487]  diff  [-2.4787487]
# true  [6.75]  pred  [8.371489]  diff  [-1.62148857]
# true  [4.25]  pred  [7.8525047]  diff  [-3.60250473]
# true  [5.75]  pred  [7.6799164]  diff  [-1.92991638]
# true  [3.5]  pred  [8.488703]  diff  [-4.98870277]
# true  [3.35]  pred  [6.6033945]  diff  [-3.25339451]
# true  [10.62]  pred  [8.136639]  diff  [2.48336136]
# true  [8.]  pred  [6.943458]  diff  [1.05654192]
# true  [4.75]  pred  [5.329972]  diff  [-0.57997179]
# true  [8.5]  pred  [7.8298244]  diff  [0.67017555]
# true  [8.85]  pred  [9.43398]  diff  [-0.58397999]
# true  [8.]  pred  [7.3287487]  diff  [0.6712513]
# true  [6.]  pred  [5.6241307]  diff  [0.37586927]
# true  [7.14]  pred  [9.375679]  diff  [-2.23567902]
# true  [3.4]  pred  [5.485821]  diff  [-2.08582077]
# true  [6.]  pred  [9.428398]  diff  [-3.42839813]
# true  [3.75]  pred  [2.443109]  diff  [1.30689096]
# true  [8.89]  pred  [5.4602933]  diff  [3.42970671]
# true  [4.35]  pred  [7.264473]  diff  [-2.91447296]
# true  [13.1]  pred  [6.4686365]  diff  [6.63136349]
# true  [4.35]  pred  [5.3716784]  diff  [-1.02167835]
# true  [3.5]  pred  [6.740613]  diff  [-3.24061298]
# true  [3.8]  pred  [7.690567]  diff  [-3.89056702]
# true  [5.26]  pred  [5.5171313]  diff  [-0.25713133]
# true  [3.35]  pred  [6.3556366]  diff  [-3.0056366]
# true  [16.26]  pred  [8.562862]  diff  [7.6971376]
# true  [4.25]  pred  [5.6004066]  diff  [-1.35040665]
# true  [4.5]  pred  [10.636923]  diff  [-6.13692284]
# true  [8.]  pred  [8.237093]  diff  [-0.23709297]
# true  [4.]  pred  [10.066163]  diff  [-6.06616306]
# true  [7.96]  pred  [8.293564]  diff  [-0.33356384]
# true  [4.]  pred  [6.707447]  diff  [-2.70744705]
# true  [4.15]  pred  [6.01159]  diff  [-1.86159]
# true  [5.95]  pred  [7.488163]  diff  [-1.53816299]
# true  [3.6]  pred  [7.683998]  diff  [-4.08399811]
# true  [8.75]  pred  [6.879837]  diff  [1.87016296]
# true  [3.4]  pred  [6.081514]  diff  [-2.68151388]
# true  [4.28]  pred  [7.9282093]  diff  [-3.6482093]
# true  [5.35]  pred  [7.552639]  diff  [-2.20263901]
# true  [5.]  pred  [7.643194]  diff  [-2.6431942]
# true  [7.65]  pred  [8.326523]  diff  [-0.67652283]
# true  [6.94]  pred  [6.594283]  diff  [0.3457169]
# true  [7.5]  pred  [7.3670707]  diff  [0.13292933]
# true  [3.6]  pred  [6.400105]  diff  [-2.800105]
# true  [1.75]  pred  [5.8991985]  diff  [-4.14919853]
# true  [3.45]  pred  [5.5122604]  diff  [-2.06226044]
# true  [9.63]  pred  [10.041816]  diff  [-0.41181576]
# true  [8.49]  pred  [7.9169283]  diff  [0.57307171]
# true  [8.99]  pred  [8.117222]  diff  [0.87277817]
# true  [3.65]  pred  [5.982551]  diff  [-2.3325511]
# true  [3.5]  pred  [6.9213986]  diff  [-3.42139864]
# true  [3.43]  pred  [5.718681]  diff  [-2.28868086]
# true  [5.5]  pred  [8.074247]  diff  [-2.57424736]
# true  [6.93]  pred  [8.944003]  diff  [-2.01400311]
# true  [3.51]  pred  [6.4686217]  diff  [-2.95862173]
# true  [3.75]  pred  [7.913406]  diff  [-4.1634059]
# true  [4.17]  pred  [7.9590907]  diff  [-3.78909071]
# true  [9.57]  pred  [6.486054]  diff  [3.08394606]
# true  [14.67]  pred  [9.338955]  diff  [5.33104507]
# true  [12.5]  pred  [8.94116]  diff  [3.5588398]
# true  [5.5]  pred  [7.6004844]  diff  [-2.10048437]
# true  [5.15]  pred  [6.1793094]  diff  [-1.02930937]
# true  [8.]  pred  [8.355713]  diff  [-0.35571289]
# true  [5.83]  pred  [6.571145]  diff  [-0.74114506]
# true  [3.35]  pred  [5.2041163]  diff  [-1.85411634]
# true  [7.]  pred  [7.6826496]  diff  [-0.68264961]
# true  [10.]  pred  [7.1607084]  diff  [2.83929157]
# true  [8.]  pred  [7.6799164]  diff  [0.32008362]
# true  [6.88]  pred  [7.591819]  diff  [-0.71181881]
# true  [5.55]  pred  [7.722374]  diff  [-2.17237396]
# true  [7.5]  pred  [5.8060293]  diff  [1.69397068]
# true  [8.93]  pred  [6.670624]  diff  [2.25937622]
# true  [9.]  pred  [7.9438596]  diff  [1.05614042]
# true  [3.5]  pred  [6.447011]  diff  [-2.94701099]
# true  [5.77]  pred  [7.840994]  diff  [-2.07099388]
# true  [25.]  pred  [7.4363422]  diff  [17.56365776]
# true  [6.85]  pred  [10.1743145]  diff  [-3.3243145]
# true  [6.5]  pred  [7.611923]  diff  [-1.11192322]
# true  [3.75]  pred  [7.4785743]  diff  [-3.72857428]
# true  [3.5]  pred  [7.052532]  diff  [-3.5525322]
# true  [4.5]  pred  [5.603877]  diff  [-1.10387707]
# true  [2.01]  pred  [5.7053986]  diff  [-3.69539856]
# true  [4.17]  pred  [9.079638]  diff  [-4.90963753]
# true  [13.]  pred  [8.928001]  diff  [4.0719986]
# true  [3.98]  pred  [7.1764884]  diff  [-3.1964884]
# true  [7.5]  pred  [7.1011386]  diff  [0.39886141]
# true  [13.12]  pred  [7.9413557]  diff  [5.17864429]
# true  [4.]  pred  [7.923056]  diff  [-3.92305613]
# true  [3.95]  pred  [6.5744257]  diff  [-2.6244257]
# true  [13.]  pred  [7.9515715]  diff  [5.04842854]
# true  [9.]  pred  [7.6004844]  diff  [1.39951563]
# true  [4.55]  pred  [5.764305]  diff  [-1.21430511]
# true  [9.5]  pred  [6.555814]  diff  [2.94418621]
# true  [4.5]  pred  [5.049588]  diff  [-0.5495882]
# true  [8.75]  pred  [7.305386]  diff  [1.44461393]
# true  [10.]  pred  [9.511025]  diff  [0.48897457]
# true  [18.]  pred  [10.925855]  diff  [7.07414532]
# true  [24.98]  pred  [11.696975]  diff  [13.28302525]
# true  [12.05]  pred  [8.06378]  diff  [3.98622017]
# true  [22.]  pred  [8.924072]  diff  [13.07592773]
# true  [8.75]  pred  [8.50185]  diff  [0.24814987]
# true  [22.2]  pred  [9.502716]  diff  [12.69728394]
# true  [17.25]  pred  [9.014976]  diff  [8.23502445]
# true  [6.]  pred  [7.993579]  diff  [-1.99357891]
# true  [8.06]  pred  [8.543715]  diff  [-0.48371452]
# true  [9.24]  pred  [8.487568]  diff  [0.7524321]
# true  [12.]  pred  [7.9559507]  diff  [4.04404926]
# true  [10.61]  pred  [9.797938]  diff  [0.81206165]
# true  [5.71]  pred  [8.486189]  diff  [-2.77618889]
# true  [10.]  pred  [6.1149106]  diff  [3.8850894]
# true  [17.5]  pred  [9.432594]  diff  [8.0674057]
# true  [15.]  pred  [10.315937]  diff  [4.68406296]
# true  [7.78]  pred  [7.9438596]  diff  [-0.16385958]
# true  [7.8]  pred  [8.916853]  diff  [-1.11685295]
# true  [10.]  pred  [9.929447]  diff  [0.07055283]
# true  [24.98]  pred  [8.120856]  diff  [16.85914371]
# true  [10.28]  pred  [8.012437]  diff  [2.26756313]
# true  [15.]  pred  [9.725502]  diff  [5.27449799]
# true  [12.]  pred  [10.796302]  diff  [1.20369816]
# true  [10.58]  pred  [9.060825]  diff  [1.51917465]
# true  [5.85]  pred  [10.044386]  diff  [-4.19438591]
# true  [11.22]  pred  [11.640691]  diff  [-0.4206908]
# true  [8.56]  pred  [8.609143]  diff  [-0.04914326]
# true  [13.89]  pred  [10.077718]  diff  [3.81228222]
# true  [5.71]  pred  [9.025604]  diff  [-3.31560425]
# true  [15.79]  pred  [9.29941]  diff  [6.49059013]
# true  [7.5]  pred  [10.16568]  diff  [-2.66567993]
# true  [11.25]  pred  [7.954502]  diff  [3.29549789]
# true  [6.15]  pred  [9.759638]  diff  [-3.60963783]
# true  [13.45]  pred  [9.940591]  diff  [3.50940914]
# true  [6.25]  pred  [8.147165]  diff  [-1.8971653]
# true  [6.5]  pred  [7.2483697]  diff  [-0.74836969]
# true  [12.]  pred  [7.2786207]  diff  [4.72137928]
# true  [8.5]  pred  [7.690567]  diff  [0.80943298]
# true  [8.]  pred  [12.573481]  diff  [-4.57348061]
# true  [5.75]  pred  [7.6010985]  diff  [-1.85109854]
# true  [15.73]  pred  [8.046555]  diff  [7.68344543]
# true  [9.86]  pred  [9.365439]  diff  [0.49456059]
# true  [13.51]  pred  [10.994432]  diff  [2.51556755]
# true  [5.4]  pred  [8.757081]  diff  [-3.35708103]
# true  [6.25]  pred  [10.444239]  diff  [-4.19423866]
# true  [5.5]  pred  [10.581153]  diff  [-5.08115292]
# true  [5.]  pred  [6.3918924]  diff  [-1.39189243]
# true  [6.25]  pred  [11.96019]  diff  [-5.71018982]
# true  [5.75]  pred  [6.1908426]  diff  [-0.44084263]
# true  [20.5]  pred  [9.929447]  diff  [10.57055283]
# true  [5.]  pred  [6.383194]  diff  [-1.38319397]
# true  [7.]  pred  [12.091295]  diff  [-5.09129524]
# true  [18.]  pred  [10.720381]  diff  [7.27961922]
# true  [12.]  pred  [11.337567]  diff  [0.66243267]
# true  [20.4]  pred  [8.223551]  diff  [12.1764492]
# true  [22.2]  pred  [11.643033]  diff  [10.55696697]
# true  [16.42]  pred  [9.651732]  diff  [6.76826756]
# true  [8.63]  pred  [6.7698774]  diff  [1.86012257]
# true  [19.38]  pred  [8.960386]  diff  [10.41961372]
# true  [14.]  pred  [9.791161]  diff  [4.20883942]
# true  [10.]  pred  [9.543629]  diff  [0.45637131]
# true  [15.95]  pred  [10.004097]  diff  [5.94590302]
# true  [20.]  pred  [10.560501]  diff  [9.4394989]
# true  [10.]  pred  [8.757081]  diff  [1.24291897]
# true  [24.98]  pred  [7.4667463]  diff  [17.51325367]
# true  [11.25]  pred  [7.7428718]  diff  [3.50712824]
# true  [22.83]  pred  [11.882557]  diff  [10.94744308]
# true  [10.2]  pred  [11.362567]  diff  [-1.16256695]
# true  [10.]  pred  [7.265697]  diff  [2.734303]
# true  [14.]  pred  [12.03948]  diff  [1.96051979]
# true  [12.5]  pred  [10.01776]  diff  [2.48223972]
# true  [5.79]  pred  [7.917691]  diff  [-2.12769123]
# true  [24.98]  pred  [11.05364]  diff  [13.92635963]
# true  [4.35]  pred  [5.803712]  diff  [-1.45371189]
# true  [11.25]  pred  [9.137384]  diff  [2.11261559]
# true  [6.67]  pred  [9.025906]  diff  [-2.35590561]
# true  [8.]  pred  [9.938393]  diff  [-1.93839264]
# true  [18.16]  pred  [9.29941]  diff  [8.86059013]
# true  [12.]  pred  [9.477314]  diff  [2.522686]
# true  [8.89]  pred  [10.658499]  diff  [-1.76849876]
# true  [9.5]  pred  [9.900381]  diff  [-0.40038109]
# true  [13.65]  pred  [9.347517]  diff  [4.30248299]
# true  [12.]  pred  [12.317539]  diff  [-0.31753922]
# true  [15.]  pred  [8.918836]  diff  [6.08116436]
# true  [12.67]  pred  [10.131275]  diff  [2.53872482]
# true  [7.38]  pred  [8.712739]  diff  [-1.33273899]
# true  [15.56]  pred  [9.141956]  diff  [6.41804367]
# true  [7.45]  pred  [7.656822]  diff  [-0.2068222]
# true  [6.25]  pred  [8.293564]  diff  [-2.04356384]
# true  [6.25]  pred  [7.8756127]  diff  [-1.62561274]
# true  [9.37]  pred  [9.180855]  diff  [0.1891452]
# true  [22.5]  pred  [10.629601]  diff  [11.87039948]
# true  [7.5]  pred  [9.422784]  diff  [-1.92278385]
# true  [7.]  pred  [7.6295557]  diff  [-0.6295557]
# true  [5.75]  pred  [6.2772493]  diff  [-0.52724934]
# true  [7.67]  pred  [8.547825]  diff  [-0.87782486]
# true  [12.5]  pred  [8.759398]  diff  [3.74060154]
# true  [16.]  pred  [7.571515]  diff  [8.42848492]
# true  [11.79]  pred  [8.220939]  diff  [3.56906132]
# true  [11.36]  pred  [8.890545]  diff  [2.46945511]
# true  [6.1]  pred  [7.9413557]  diff  [-1.84135571]
# true  [23.25]  pred  [11.325844]  diff  [11.92415619]
# true  [19.88]  pred  [8.079214]  diff  [11.8007859]
# true  [15.38]  pred  [11.1520405]  diff  [4.22795952]

# %% [markdown]
# Save the model using load_model (check the lecture slides)

# %% [markdown]
# import the module first

# %%
from keras.models import load_model

# %% [markdown]
# Save the model to the .h5 file

# %%
model.save('dl_lab_3.h5')

# %%
my_model = load_model('dl_lab_3.h5')
