# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Salary_Data.csv")
X = df.iloc[:, :1].values
y = df.iloc[:, 1:].values
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X, y)
lin_pred = regressor.predict(X)

# %%
for test, pred in zip(y, lin_pred):
    print(test, "  ", pred)
# Out:
# [39343.]    [36187.15875227]
# [46205.]    [38077.15121656]
# [37731.]    [39967.14368085]
# [43525.]    [44692.12484158]
# [39891.]    [46582.11730587]
# [56642.]    [53197.09093089]
# [60150.]    [54142.08716303]
# [54445.]    [56032.07962732]
# [64445.]    [56032.07962732]
# [57189.]    [60757.06078805]
# [63218.]    [62647.05325234]
# [55794.]    [63592.04948449]
# [56957.]    [63592.04948449]
# [57081.]    [64537.04571663]
# [61111.]    [68317.03064522]
# [67938.]    [72097.0155738]
# [66029.]    [73987.00803809]
# [83088.]    [75877.00050238]
# [81363.]    [81546.97789525]
# [93940.]    [82491.9741274]
# [91738.]    [90051.94398456]
# [98273.]    [92886.932681]
# [101302.]    [100446.90253816]
# [113812.]    [103281.8912346]
# [109431.]    [108006.87239533]
# [105582.]    [110841.86109176]
# [116969.]    [115566.84225249]
# [112635.]    [116511.83848464]
# [122391.]    [123126.81210966]
# [121872.]    [125016.80457395]

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
poly_reg.fit(X_poly, y)
# Out:
# PolynomialFeatures(degree=4, include_bias=True, interaction_only=False)

# %%
lin_reg2 = LinearRegression()
lin_reg2.fit(X_poly, y)
lin_pred2 = lin_reg2.predict(poly_reg.fit_transform(X))

# %%
plt.title("Polynomial Regression")
plt.xlabel("Position")
plt.ylabel("Salary")
plt.scatter(X, y, color="red")
plt.plot(X, lin_pred, color="blue")
plt.plot(X, lin_pred2, color="green")
plt.show()

# %%
for pred2, test, pred in zip(lin_pred2, y, lin_pred):
    print(pred2, "  ", test, "  ", pred)
# Out:
# [40817.08411633]    [39343.]    [36187.15875227]
# [41386.56344571]    [46205.]    [38077.15121656]
# [42124.63113407]    [37731.]    [39967.14368085]
# [44642.00150505]    [43525.]    [44692.12484158]
# [45892.3634521]    [39891.]    [46582.11730587]
# [51192.6748916]    [56642.]    [53197.09093089]
# [52052.25315561]    [60150.]    [54142.08716303]
# [53837.34635589]    [54445.]    [56032.07962732]
# [53837.34635589]    [64445.]    [56032.07962732]
# [58636.11441369]    [57189.]    [60757.06078805]
# [60668.78813138]    [63218.]    [62647.05325234]
# [61705.4459881]    [55794.]    [63592.04948449]
# [61705.4459881]    [56957.]    [63592.04948449]
# [62754.37697656]    [57081.]    [64537.04571663]
# [67054.19197705]    [61111.]    [68317.03064522]
# [71477.23419847]    [67938.]    [72097.0155738]
# [73717.5661678]    [66029.]    [73987.00803809]
# [75968.20390891]    [83088.]    [75877.00050238]
# [82718.49988191]    [81363.]    [81546.97789525]
# ...
